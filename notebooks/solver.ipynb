# %%
# Add the backend directory to the Python path
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from backend.classes.cube import RubikEnv
from backend.classes.agent import RubikAgent
from backend.visualization.functions import showCube

# %%
cube = RubikEnv()
agent = RubikAgent(cube)
path = "../data/qtable/qtable_1.json"
agent.loadQtableFromFile(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 agent = RubikAgent(cube)
#       3 path = "../data/qtable/qtable_1.json"
# ----> 4 agent.loadQtableFromFile(path)
#
# File d:\coding\pubblic\rubik\rubik2\backend\classes\agent.py:306, in RubikAgent.loadQtableFromFile(self, filepath)
#     302 def loadQtableFromFile(self, filepath: str) -> None:
#     303     """
#     304     Loads the Q-table from the specified file.
#     305     """
# --> 306     with open(filepath, 'r') as f:
#     307         qtable_data = json.load(f)
#     308         self.qTable = {int(k): np.array(v) for k, v in qtable_data.items()}
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/qtable/qtable_1.json'

# %%
cube.reset()
shuffles = cube.shuffle(3)
showCube(cube.convert_matrix_to_cross().copy())

# %%
history = agent.solveCube(maxSteps=20, verbose=True)

# %%
shuffles , history
